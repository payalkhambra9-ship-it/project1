# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price  ...  power          brand
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  ...  110.0            TVS
# 1               Royal Enfield Classic 350cc  119900.0  ...  350.0  Royal Enfield
# 2                      Triumph Daytona 675R  600000.0  ...  675.0        Triumph
# 3                      TVS Apache RTR 180cc   65000.0  ...  180.0            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  ...  150.0         Yamaha
# ...                                     ...       ...  ...    ...            ...
# 32643                Hero Passion Pro 100cc   39000.0  ...  100.0           Hero
# 32644                  TVS Apache RTR 180cc   30000.0  ...  180.0            TVS
# 32645              Bajaj Avenger Street 220   60000.0  ...  220.0          Bajaj
# 32646             Hero Super Splendor 125cc   15600.0  ...  125.0           Hero
# 32647                    Bajaj Pulsar 150cc   22000.0  ...  150.0          Bajaj
#
# ...

# %%
df.info() ####for all information about datatype
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df.columns ### for all the columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
df.bike_name ###for particular coulumn
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: str

# %%
df.owner
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4        First Owner
#             ...
# 32643    First Owner
# 32644    First Owner
# 32645    First Owner
# 32646    First Owner
# 32647    First Owner
# Name: owner, Length: 32648, dtype: str

# %%
df.brand
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: str

# %%
df['brand'] #### for view a column
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: str

# %%
df[['owner']] ### a particular way to view a coulmn
# Out:
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4      First Owner
# ...            ...
# 32643  First Owner
# 32644  First Owner
# 32645  First Owner
# 32646  First Owner
# 32647  First Owner
#
# [32648 rows x 1 columns]

# %%
df[['power']]
# Out:
#        power
# 0      110.0
# 1      350.0
# 2      675.0
# 3      180.0
# 4      150.0
# ...      ...
# 32643  100.0
# 32644  180.0
# 32645  220.0
# 32646  125.0
# 32647  150.0
#
# [32648 rows x 1 columns]

# %%
df.head() #### to view first 5 rows by default,dp.head(10)>>>>> according to user requirement
# Out:
#                               bike_name     price  ...  power          brand
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  ...  110.0            TVS
# 1           Royal Enfield Classic 350cc  119900.0  ...  350.0  Royal Enfield
# 2                  Triumph Daytona 675R  600000.0  ...  675.0        Triumph
# 3                  TVS Apache RTR 180cc   65000.0  ...  180.0            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  ...  150.0         Yamaha
#
# [5 rows x 8 columns]

# %%
df.tail() #### last 5 rows by default,dp.tail(10)>>>>according to  user
# Out:
#                        bike_name    price    city  ...   age  power  brand
# 32643     Hero Passion Pro 100cc  39000.0   Delhi  ...   4.0  100.0   Hero
# 32644       TVS Apache RTR 180cc  30000.0  Karnal  ...   9.0  180.0    TVS
# 32645   Bajaj Avenger Street 220  60000.0   Delhi  ...   6.0  220.0  Bajaj
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur  ...  16.0  125.0   Hero
# 32647         Bajaj Pulsar 150cc  22000.0    Pune  ...  13.0  150.0  Bajaj
#
# [5 rows x 8 columns]

# %%
df.duplicated() ### for duplicates values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum() ### for count all the duplicates
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()
# Out:
#                                  bike_name     price  ...  power            brand
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  ...  110.0              TVS
# 1              Royal Enfield Classic 350cc  119900.0  ...  350.0    Royal Enfield
# 2                     Triumph Daytona 675R  600000.0  ...  675.0          Triumph
# 3                     TVS Apache RTR 180cc   65000.0  ...  180.0              TVS
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  ...  150.0           Yamaha
# ...                                    ...       ...  ...    ...              ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0  ...  150.0             Hero
# 9369                   Bajaj Avenger 220cc   35000.0  ...  220.0            Bajaj
# 9370        Harley-Davidson Street 750 ABS  450000.0  ...  750.0  Harley-Davidson
# 9371                 Bajaj Dominar 400 ABS  139000.0  ...  400.0            Bajaj
# ...

# %%
df.drop_duplicates(inplace=True) #### for remove the duplicate where is true

# %%
df.drop_duplicates().sum()
# Out:
# bike_name     TVS Star City Plus Dual Tone 110ccRoyal Enfiel...
# price                                               621689684.0
# city          AhmedabadDelhiDelhiBangaloreBangaloreDelhiDelh...
# kms_driven                                          175120477.0
# owner         First OwnerFirst OwnerFirst OwnerFirst OwnerFi...
# age                                                     48752.0
# power                                                 1670849.0
# brand         TVSRoyal EnfieldTriumphTVSYamahaYamahaHondaHer...
# dtype: object

# %%
df.duplicated().sum() #### no duplicate
# Out:
# np.int64(0)

# %%
df.isnull()  #### for return value
# Out:
#       bike_name  price   city  kms_driven  owner    age  power  brand
# 0         False  False  False       False  False  False  False  False
# 1         False  False  False       False  False  False  False  False
# 2         False  False  False       False  False  False  False  False
# 3         False  False  False       False  False  False  False  False
# 4         False  False  False       False  False  False  False  False
# ...         ...    ...    ...         ...    ...    ...    ...    ...
# 9362      False  False  False       False  False  False  False  False
# 9369      False  False  False       False  False  False  False  False
# 9370      False  False  False       False  False  False  False  False
# 9371      False  False  False       False  False  False  False  False
# 9372      False  False  False       False  False  False  False  False
#
# [7324 rows x 8 columns]

# %%
df.isnull().sum() #### for calculting the null value
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace=True)  #### for remove the null values

# %%
df['owner'].unique() ### for find the unique value
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df['owner'].nunique() ####  count the no. of unique value
# Out:
# 4

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df['brand'].value_counts() #### count the elements value
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
# df.drop('city',axis=1,inplace=True) ### for remove the column

# %%
df
# Out:
#                                  bike_name     price  ...  power            brand
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  ...  110.0              TVS
# 1              Royal Enfield Classic 350cc  119900.0  ...  350.0    Royal Enfield
# 2                     Triumph Daytona 675R  600000.0  ...  675.0          Triumph
# 3                     TVS Apache RTR 180cc   65000.0  ...  180.0              TVS
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  ...  150.0           Yamaha
# ...                                    ...       ...  ...    ...              ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0  ...  150.0             Hero
# 9369                   Bajaj Avenger 220cc   35000.0  ...  220.0            Bajaj
# 9370        Harley-Davidson Street 750 ABS  450000.0  ...  750.0  Harley-Davidson
# 9371                 Bajaj Dominar 400 ABS  139000.0  ...  400.0            Bajaj
# ...

# %%
###df.drop(['city','bike_name'], axis=1 ,inplace=True) ### for two column

# %%
df
# Out:
#                                  bike_name     price  ...  power            brand
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  ...  110.0              TVS
# 1              Royal Enfield Classic 350cc  119900.0  ...  350.0    Royal Enfield
# 2                     Triumph Daytona 675R  600000.0  ...  675.0          Triumph
# 3                     TVS Apache RTR 180cc   65000.0  ...  180.0              TVS
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  ...  150.0           Yamaha
# ...                                    ...       ...  ...    ...              ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0  ...  150.0             Hero
# 9369                   Bajaj Avenger 220cc   35000.0  ...  220.0            Bajaj
# 9370        Harley-Davidson Street 750 ABS  450000.0  ...  750.0  Harley-Davidson
# 9371                 Bajaj Dominar 400 ABS  139000.0  ...  400.0            Bajaj
# ...

# %%
char=df.select_dtypes(include='O')  ### and also object both can used
char                                #### it is used for print the all string
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3168\398533676.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char=df.select_dtypes(include='O')  ### and also object both can used
#                                  bike_name  ...            brand
# 0       TVS Star City Plus Dual Tone 110cc  ...              TVS
# 1              Royal Enfield Classic 350cc  ...    Royal Enfield
# 2                     Triumph Daytona 675R  ...          Triumph
# 3                     TVS Apache RTR 180cc  ...              TVS
# ...

# %%
iint=df.select_dtypes(exclude='object') ### for intergers printing
iint
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
df.drop(['city','bike_name'], axis=1 ,inplace=True)
df
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df[df['owner']=='Second Owner'] #### for find selective element detail
# Out:
#          price  kms_driven         owner   age  power          brand
# 9      88000.0     19000.0  Second Owner   7.0  500.0  Royal Enfield
# 18    240000.0     15025.0  Second Owner   3.0  302.0        Benelli
# 27     20800.0     30500.0  Second Owner   7.0  125.0          Honda
# 31     80000.0     20000.0  Second Owner   4.0  150.0         Yamaha
# 35     70000.0    100000.0  Second Owner   8.0  200.0            KTM
# ...        ...         ...           ...   ...    ...            ...
# 9196  116900.0     25362.0  Second Owner   6.0  500.0  Royal Enfield
# 9198   83800.0     21540.0  Second Owner  10.0  350.0  Royal Enfield
# 9260  120000.0     14000.0  Second Owner   4.0  250.0          Honda
# 9339   11400.0     20000.0  Second Owner  17.0  100.0           Hero
# 9340   34400.0     24513.0  Second Owner   8.0  150.0          Honda
#
# [588 rows x 6 columns]

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df[df['brand']=='BMW']
# Out:
#           price  kms_driven        owner  age   power brand
# 359    255000.0      2200.0  First Owner  3.0   310.0   BMW
# 567    260000.0      8500.0  First Owner  3.0   310.0   BMW
# 1157   270000.0     12872.0  First Owner  2.0   310.0   BMW
# 2612   350000.0     14482.0  First Owner  2.0   310.0   BMW
# 2956   360000.0      7093.0  First Owner  3.0   310.0   BMW
# 3016  1500000.0     18000.0  First Owner  4.0  1000.0   BMW
# 4864  1800000.0      2600.0  First Owner  4.0  1000.0   BMW
# 6070  1350000.0      4600.0  First Owner  3.0   850.0   BMW
# 7597   260000.0     11000.0  First Owner  3.0   310.0   BMW
# 8510   330000.0      4241.0  First Owner  3.0   310.0   BMW

# %%
honda_bike=df[df['brand']=='Honda']

# %%
ho=honda_bike[honda_bike['owner']=='First Owner']
ho
# Out:
#         price  kms_driven        owner   age  power  brand
# 6     85000.0      8200.0  First Owner   3.0  160.0  Honda
# 29    81200.0      9100.0  First Owner   2.0  160.0  Honda
# 34    40000.0     30000.0  First Owner   8.0  150.0  Honda
# 37    65000.0     43000.0  First Owner   6.0  150.0  Honda
# 56    34500.0     17056.0  First Owner   5.0  110.0  Honda
# ...       ...         ...          ...   ...    ...    ...
# 9234  46000.0      9000.0  First Owner   5.0  110.0  Honda
# 9239  35000.0     14992.0  First Owner   8.0  110.0  Honda
# 9250  80000.0      8000.0  First Owner  10.0  250.0  Honda
# 9258  65000.0     18000.0  First Owner   6.0  160.0  Honda
# 9346  61483.0     28032.0  First Owner   7.0  150.0  Honda
#
# [617 rows x 6 columns]

# %%
x=ho[ho['age']<2]
x
# Out:
#         price  kms_driven        owner  age  power  brand
# 344   81500.0      3000.0  First Owner  1.0  125.0  Honda
# 7235  60000.0        74.0  First Owner  1.0  110.0  Honda

# %%
bmw=df[(df['brand']=='BMW') &( df['owner']=='First Owner')] ### for multiple condition
bmw
# Out:
#           price  kms_driven        owner  age   power brand
# 359    255000.0      2200.0  First Owner  3.0   310.0   BMW
# 567    260000.0      8500.0  First Owner  3.0   310.0   BMW
# 1157   270000.0     12872.0  First Owner  2.0   310.0   BMW
# 2612   350000.0     14482.0  First Owner  2.0   310.0   BMW
# 2956   360000.0      7093.0  First Owner  3.0   310.0   BMW
# 3016  1500000.0     18000.0  First Owner  4.0  1000.0   BMW
# 4864  1800000.0      2600.0  First Owner  4.0  1000.0   BMW
# 6070  1350000.0      4600.0  First Owner  3.0   850.0   BMW
# 7597   260000.0     11000.0  First Owner  3.0   310.0   BMW
# 8510   330000.0      4241.0  First Owner  3.0   310.0   BMW

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict={
    'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4 ##owner dict that use in map function
}

# %%
df['owner']=df['owner'].map(owner_dict) ### encode the string into integer

# %%
df
# Out:
#          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
brand_dict={
     'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23
}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df #### map function run in another cell
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0      1  3.0  110.0      1
# 1     119900.0     11000.0      1  4.0  350.0      2
# 2     600000.0       110.0      1  8.0  675.0      3
# 3      65000.0     16329.0      1  4.0  180.0      1
# 4      80000.0     10000.0      1  3.0  150.0      4
# ...        ...         ...    ...  ...    ...    ...
# 9362   25000.0     48587.0      1  8.0  150.0      6
# 9369   35000.0     60000.0      1  9.0  220.0      7
# 9370  450000.0      3430.0      1  4.0  750.0     15
# 9371  139000.0     21300.0      1  4.0  400.0      7
# 9372   80000.0      7127.0      1  5.0  220.0      7
#
# [7324 rows x 6 columns]

# %%
df.rename(columns={'age':'model age'},inplace=True)

# %%
df
# Out:
#          price  kms_driven  owner  model age  power  brand
# 0      35000.0     17654.0      1        3.0  110.0      1
# 1     119900.0     11000.0      1        4.0  350.0      2
# 2     600000.0       110.0      1        8.0  675.0      3
# 3      65000.0     16329.0      1        4.0  180.0      1
# 4      80000.0     10000.0      1        3.0  150.0      4
# ...        ...         ...    ...        ...    ...    ...
# 9362   25000.0     48587.0      1        8.0  150.0      6
# 9369   35000.0     60000.0      1        9.0  220.0      7
# 9370  450000.0      3430.0      1        4.0  750.0     15
# 9371  139000.0     21300.0      1        4.0  400.0      7
# 9372   80000.0      7127.0      1        5.0  220.0      7
#
# [7324 rows x 6 columns]

# %%
df.drop('price',axis=1)  ### for tempory remove the coumnl
# Out:
#       kms_driven  owner  model age  power  brand
# 0        17654.0      1        3.0  110.0      1
# 1        11000.0      1        4.0  350.0      2
# 2          110.0      1        8.0  675.0      3
# 3        16329.0      1        4.0  180.0      1
# 4        10000.0      1        3.0  150.0      4
# ...          ...    ...        ...    ...    ...
# 9362     48587.0      1        8.0  150.0      6
# 9369     60000.0      1        9.0  220.0      7
# 9370      3430.0      1        4.0  750.0     15
# 9371     21300.0      1        4.0  400.0      7
# 9372      7127.0      1        5.0  220.0      7
#
# [7324 rows x 5 columns]

# %%
y=df[['price']] ### y denotes the price coulmn

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
x=df.drop('price',axis=1)

# %%
df.to_csv('clean_bike.csv') #### for save the file

# %%
df.isnull().sum() ###for null all the columns
# Out:
# price         0
# kms_driven    0
# owner         0
# model age     0
# power         0
# brand         0
# dtype: int64

# %%
import sklearn as sns

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (5859, 5) (1465, 5) (5859, 1) (1465, 1)

# %%
x_train
# Out:
#       kms_driven  owner  model age  power  brand
# 5789     68857.0      1       15.0  110.0      1
# 3451      5740.0      1        6.0  500.0      2
# 735      28329.0      1        6.0  110.0      6
# 7533     42966.0      1        7.0  150.0      4
# 8461      8000.0      1        5.0  500.0      2
# ...          ...    ...        ...    ...    ...
# 6522     56000.0      1        9.0  200.0      7
# 6583     22493.0      1        5.0  500.0      2
# 6856     17477.0      1        5.0  150.0      7
# 1028     14836.0      1        8.0  150.0      4
# 9250      8000.0      1       10.0  250.0      5
#
# [5859 rows x 5 columns]

# %%
y_train
# Out:
#          price
# 5789   18000.0
# 3451  140000.0
# 735    32000.0
# 7533   40000.0
# 8461  160000.0
# ...        ...
# 6522   48928.0
# 6583  114000.0
# 6856   41000.0
# 1028   40000.0
# 9250   80000.0
#
# [5859 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)  ###value insert
# Out:
# LinearRegression()

# %%
x_test
# Out:
#       kms_driven  owner  model age  power  brand
# 4909     22500.0      1        6.0  350.0      2
# 1942      3198.0      1        5.0  500.0      2
# 5763     15000.0      1        6.0  220.0      7
# 4800     27000.0      1       12.0  150.0      4
# 7614     16764.0      1        9.0  100.0      6
# ...          ...    ...        ...    ...    ...
# 5653     16523.0      1        5.0  750.0     15
# 609       2881.0      1        7.0  250.0     14
# 4211     23833.0      1        4.0  150.0      8
# 6379      9282.0      1        7.0  500.0      2
# 647       2980.0      1        6.0  160.0      1
#
# [1465 rows x 5 columns]

# %%
pred=lr.predict(x_test)

# %%
honda_bike=[[22500.0,	1,	6.0, 	350.0,	2]]

# %%
lst=[[22500.0,	1,	6.0, 	350.0,	2]]

# %%
lr.predict(lst)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[125382.54523531]])

# %%
lr.predict(honda_bike)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[125382.54523531]])

# %%
pred
# Out:
# array([[125382.54523531],
#        [216422.20333617],
#        [ 96966.48595241],
#        ...,
#        [ 72233.83615101],
#        [208856.67620686],
#        [  9305.60087569]], shape=(1465, 1))

# %%
y_test
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0
# ...        ...
# 5653  395000.0
# 609   140000.0
# 4211   54500.0
# 6379  114000.0
# 647    36000.0
#
# [1465 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rfg = RandomForestRegressor()

# %%
rfg.fit(x_train, y_train)
honda_bike =[[35000.0, 1, 9.0, 250.0, 5]]
rfg.predict(honda_bike)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([77430.98])

# %%
x_test
# Out:
#       kms_driven  owner  model age  power  brand
# 4909     22500.0      1        6.0  350.0      2
# 1942      3198.0      1        5.0  500.0      2
# 5763     15000.0      1        6.0  220.0      7
# 4800     27000.0      1       12.0  150.0      4
# 7614     16764.0      1        9.0  100.0      6
# ...          ...    ...        ...    ...    ...
# 5653     16523.0      1        5.0  750.0     15
# 609       2881.0      1        7.0  250.0     14
# 4211     23833.0      1        4.0  150.0      8
# 6379      9282.0      1        7.0  500.0      2
# 647       2980.0      1        6.0  160.0      1
#
# [1465 rows x 5 columns]

# %%
pred =rfg.predict(x_test)

# %%
pred
# Out:
# array([109527.04545455, 150445.        ,  50496.05      , ...,
#         51620.        , 105945.77      ,  75001.08333333], shape=(1465,))

# %%
y_test
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0
# ...        ...
# 5653  395000.0
# 609   140000.0
# 4211   54500.0
# 6379  114000.0
# 647    36000.0
#
# [1465 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, SVR

# %%
df
# Out:
#          price  kms_driven  owner  model age  power  brand
# 0      35000.0     17654.0      1        3.0  110.0      1
# 1     119900.0     11000.0      1        4.0  350.0      2
# 2     600000.0       110.0      1        8.0  675.0      3
# 3      65000.0     16329.0      1        4.0  180.0      1
# 4      80000.0     10000.0      1        3.0  150.0      4
# ...        ...         ...    ...        ...    ...    ...
# 9362   25000.0     48587.0      1        8.0  150.0      6
# 9369   35000.0     60000.0      1        9.0  220.0      7
# 9370  450000.0      3430.0      1        4.0  750.0     15
# 9371  139000.0     21300.0      1        4.0  400.0      7
# 9372   80000.0      7127.0      1        5.0  220.0      7
#
# [7324 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       7324 non-null   float64
#  1   kms_driven  7324 non-null   float64
#  2   owner       7324 non-null   int64
#  3   model age   7324 non-null   float64
#  4   power       7324 non-null   float64
#  5   brand       7324 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 400.5 KB

# %%
df['price'].value_counts()
# Out:
# price
# 35000.0     183
# 25000.0     179
# 30000.0     154
# 45000.0     136
# 20000.0     134
#            ...
# 139100.0      1
# 115800.0      1
# 65450.0       1
# 11400.0       1
# 61483.0       1
# Name: count, Length: 1232, dtype: int64

# %%
x=df.drop('price', axis=1)
y =df[['price']]

# %%
x
# Out:
#       kms_driven  owner  model age  power  brand
# 0        17654.0      1        3.0  110.0      1
# 1        11000.0      1        4.0  350.0      2
# 2          110.0      1        8.0  675.0      3
# 3        16329.0      1        4.0  180.0      1
# 4        10000.0      1        3.0  150.0      4
# ...          ...    ...        ...    ...    ...
# 9362     48587.0      1        8.0  150.0      6
# 9369     60000.0      1        9.0  220.0      7
# 9370      3430.0      1        4.0  750.0     15
# 9371     21300.0      1        4.0  400.0      7
# 9372      7127.0      1        5.0  220.0      7
#
# [7324 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# Assuming you want to split y into train and test sets
x_train , x_test , y_train, y_test = train_test_split(x , y, test_size=0.2, random_state=42)

y_test
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0
# ...        ...
# 5653  395000.0
# 609   140000.0
# 4211   54500.0
# 6379  114000.0
# 647    36000.0
#
# [1465 rows x 1 columns]

# %%
x_train ,x_test,y_train,y_test = train_test_split(x , y, test_size=0.2, random_state=42)

# %%
sv = SVR()

# %%
sv.fit(x_train, y_train)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
sv.score(x_test, y_test)
# Out:
# -0.058810958372743416

# %%
pred=sv.predict(x_test)
pred
# Out:
# array([54600.4698477 , 55129.47131119, 54861.78539028, ...,
#        54550.9225554 , 55020.38248866, 55131.93435183], shape=(1465,))

# %%
pred[0:10]
# Out:
# array([54600.4698477 , 55129.47131119, 54861.78539028, 54433.67728621,
#        54804.26431787, 55109.94158252, 53983.67981309, 55153.44041585,
#        54829.56379125, 54856.99083596])

# %%
y_test[0:10]
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0
# 5129  141000.0
# 8349   35000.0
# 1874  140000.0
# 2427   32500.0
# 5567   85000.0

# %%
price_value_count = df['price'].value_counts()

# %%
plt.bar(price_value_count.index, price_value_count.values)
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Price Distribution')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
sv = DecisionTreeClassifier(criterion='gini')
sv.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
sv.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=sv.predict(x_test)

# %%
pred
# Out:
# array([109400., 158300.,  40900., ...,  50000., 102000.,  39000.],
#       shape=(1465,))

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train, y_train)
# Out:
# 0.9978509922887903

# %%
dtr.score(x_test, y_test)
# Out:
# 0.8445777363131278

# %%
dtr.predict(x_test)
# Out:
# array([109400., 158300.,  50450., ...,  50000., 102000.,  66000.],
#       shape=(1465,))

# %%
y_test
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0
# ...        ...
# 5653  395000.0
# 609   140000.0
# 4211   54500.0
# 6379  114000.0
# 647    36000.0
#
# [1465 rows x 1 columns]

# %%
import joblib

# %%
joblib.dump(lr, "linear_model.lb")
# Out:
# ['linear_model.lb']

# %%
model=joblib.load("linear_model.lb")

# %%
model.predict(x_test)
# Out:
# array([[125382.54523531],
#        [216422.20333617],
#        [ 96966.48595241],
#        ...,
#        [ 72233.83615101],
#        [208856.67620686],
#        [  9305.60087569]], shape=(1465, 1))
